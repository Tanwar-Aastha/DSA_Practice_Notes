# %% [markdown]
# ## Data Types
#
# - **Numeric Types:**
#
#   `int` for integers (unlimited size).
#
#   `float` for decimal numbers (double precision).
#
#   `complex` for complex numbers (3+5j).
#
# - **Sequence Types:** `list`, `tuple`, and `range` for ordered collections.
# - **Text Type:** `str` for strings.
# - **Mapping Type:** `dict` for key-value pairs.
# - **Set Types:** `set` and `frozenset` for unordered collections of unique elements.
# - **Boolean Type:** `bool` for logical operations.

# %% [markdown]
# ## **TIME COMPLEXITY**

# %% [markdown]
# the time complexity of a particular code `depends on the given input size`, not on the machine used to run the code.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **1. Best Case-** where the code takes the least amount of time to get executed.
#
# For example, if the mark is 10(i.e. < 25), only the first line will be executed and the rest of the lines will be skipped. So, the least amount of steps i.e. only 2 steps are required in this case.
#
# **2. Worst Case-** where the code takes the maximum amount of time to get executed.
#
# For example, if the mark is 70(i.e. > 65), the last line will be executed after checking all the above conditions. So, the maximum amount of steps i.e. 4 steps are required in this case.
#
# **3. Average Case-** Case b/w best & worst

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ***LIST***
# ![image.png](attachment:image.png)
#
# ## ***SET***
# ![image-2.png](attachment:image-2.png)
#
# ## ***DICTIONARY***
# ![image-3.png](attachment:image-3.png)
